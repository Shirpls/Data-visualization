# %%
# Import required libraries



# Create a dash application
app = JupyterDash(__name__)
#JupyterDash.infer_jupyter_proxy_config()

# REVIEW1: Clear the layout and do not display exception till callback gets executed
app.config.suppress_callback_exceptions = True

# Read the airline data into pandas dataframe
airline_data =  pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DV0101EN-SkillsNetwork/Data%20Files/airline_data.csv', 
                            encoding = "ISO-8859-1",
                            dtype={'Div1Airport': str, 'Div1TailNum': str, 
                                   'Div2Airport': str, 'Div2TailNum': str})


# List of years 
year_list = [i for i in range(2005, 2021, 1)]

"""Compute graph data for creating yearly airline performance report 

Function that takes airline data as input and create 5 dataframes based on the grouping condition to be used for plottling charts and grphs.

Argument:
     
    df: Filtered dataframe
    
Returns:
   Dataframes to create graph. 
"""
def compute_data_choice_1(df):
    # Cancellation Category Count
    bar_data = df.groupby(['Month','CancellationCode'])['Flights'].sum().reset_index()
    # Average flight time by reporting airline
    line_data = df.groupby(['Month','Reporting_Airline'])['AirTime'].mean().reset_index()
    # Diverted Airport Landings
    div_data = df[df['DivAirportLandings'] != 0.0]
    # Source state count
    map_data = df.groupby(['OriginState'])['Flights'].sum().reset_index()
    # Destination state count
    tree_data = df.groupby(['DestState', 'Reporting_Airline'])['Flights'].sum().reset_index()
    return bar_data, line_data, div_data, map_data, tree_data


"""Compute graph data for creating yearly airline delay report

This function takes in airline data and selected year as an input and performs computation for creating charts and plots.

Arguments:
    df: Input airline data.
    
Returns:
    Computed average dataframes for carrier delay, weather delay, NAS delay, security delay, and late aircraft delay.
"""
def compute_data_choice_2(df):
    # Compute delay averages
    avg_car = df.groupby(['Month','Reporting_Airline'])['CarrierDelay'].mean().reset_index()
    avg_weather = df.groupby(['Month','Reporting_Airline'])['WeatherDelay'].mean().reset_index()
    avg_NAS = df.groupby(['Month','Reporting_Airline'])['NASDelay'].mean().reset_index()
    avg_sec = df.groupby(['Month','Reporting_Airline'])['SecurityDelay'].mean().reset_index()
    avg_late = df.groupby(['Month','Reporting_Airline'])['LateAircraftDelay'].mean().reset_index()
    return avg_car, avg_weather, avg_NAS, avg_sec, avg_late


# Application layout
app.layout = html.Div(children=[  html.H1('US Domestic Airline Flights Performance', 
                                         style={'textAlign': "center", 'color': '#503D36', 'font-size': 24}),
                                # TODO1: Add title to the dashboard
                              
    
                                # REVIEW2: Dropdown creation
                                # Create an outer division 
                                html.Div([
                                    # Add an division
                                    html.Div([
                                        # Create an division for adding dropdown helper text for report type
                                        html.Div(
                                            [
                                            html.H2('Report Type:', style={'margin-right': '2em'}),
                                            ]
                                        ),
                                        # TODO2: Add a dropdown
                                        dcc.Dropdown(id='input-type',
                                                    options=[{'label':'Yearly Airline Performance Report', 'value': 'OPT1'},
                                                            {'label':'Yearly Average Flight Delay Statistics', 'value': 'OPT2'}],
                                                    placeholder='Select a Report Type',
                                                    style={'width': '80%', 'padding': '3px', 'font-size': 20, 'text-align-last': 'center'}),
                                    # Place them next to each other using the division style
                                    ], style={'display':'flex'}),
                                    
                                   # Add next division 
                                   html.Div([
                                       # Create an division for adding dropdown helper text for choosing year
                                        html.Div(
                                            [
                                            html.H2('Choose Year:', style={'margin-right': '2em'})
                                            ]
                                        ),
                                        dcc.Dropdown(id='input-year', 
                                                     # Update dropdown values using list comphrehension
                                                     options=[{'label': i, 'value': i} for i in year_list],
                                                     placeholder="Select a year",
                                                     style={'width':'80%', 'padding':'3px', 'font-size': '20px', 'text-align-last' : 'center'}),
                                            # Place them next to each other using the division style
                                            ], style={'display': 'flex'}),  
                                          ]),
                                
                                # Add Computed graphs
                                # REVIEW3: Observe how we add an empty division and providing an id that will be updated during callback
                                html.Div([ ], id='plot1'),
    
                                html.Div([
                                        html.Div([ ], id='plot2'),
                                        html.Div([ ], id='plot3')
                                ], style={'display': 'flex'}),
                                
                                html.Div([
                                    html.Div([ ], id='plot4'),
                                    html.Div([ ], id='plot5')
                                ], style={'display': 'flex'}),
                                
                                # TODO3: Add a division with two empty divisions inside. See above disvision for example.
                             
                                ])

# Callback function definition
# TODO4: Add 5 ouput components
@app.callback( [Output(component_id='plot1', component_property='children'),
               Output(component_id='plot2', component_property='children'),
               Output(component_id='plot3', component_property='children'),
               Output(component_id='plot4', component_property='children'),
               Output(component_id='plot5', component_property='children')],
               [Input(component_id='input-type', component_property='value'),
                Input(component_id='input-year', component_property='value')],
               # REVIEW4: Holding output state till user enters all the form information. In this case, it will be chart type and year
               [State("plot1", 'children'), State("plot2", "children"),
                State("plot3", "children"), State("plot4", "children"),
                State("plot5", "children")
               ])
# Add computation to callback function and return graph
def get_graph(chart, year, children1, children2, c3, c4, c5):
      
        # Select data
        df =  airline_data[airline_data['Year']==int(year)]
       
        if chart == 'OPT1':
            # Compute required information for creating graph from the data
            bar_data, line_data, div_data, map_data, tree_data = compute_data_choice_1(df)
            
            # Number of flights under different cancellation categories
            bar_fig = px.bar(bar_data, x='Month', y='Flights', color='CancellationCode', title='Monthly Flight Cancellation')
            
            # TODO5: Average flight time by reporting airline
            
            line_fig = px.line(line_data, x="Month", y="AirTime", color='Reporting Airline', title='Average monthly flight time (minutes) by airline')
            
            
            # Percentage of diverted airport landings per reporting airline
            pie_fig = px.pie(div_data, values='Flights', names='Reporting_Airline', title='% of flights by reporting airline')
            
            # REVIEW5: Number of flights flying from each state using choropleth
            map_fig = px.choropleth(map_data,  # Input data
                    locations='OriginState', 
                    color='Flights',  
                    hover_data=['OriginState', 'Flights'], 
                    locationmode = 'USA-states', # Set to plot as US States
                    color_continuous_scale='GnBu',
                    range_color=[0, map_data['Flights'].max()]) 
            map_fig.update_layout(
                    title_text = 'Number of flights from origin state', 
                    geo_scope='usa') # Plot only the USA instead of globe
            
            # TODO6: Number of flights flying to each state from each reporting airline
            tree_fig = px.treemap(tree_data, path=['DestState', 'Reporting_Airline'],
                                 values='Flights',
                                 color='Flights',
                                 color_continuous_scale='RdBu',
                                 title='Flight count by airline to destination state'),
            
            
            # REVIEW6: Return dcc.Graph component to the empty division
            return [dcc.Graph(figure=tree_fig), 
                    dcc.Graph(figure=pie_fig),
                    dcc.Graph(figure=map_fig),
                    dcc.Graph(figure=bar_fig),
                    dcc.Graph(figure=line_fig)
                   ]
        else:
            # REVIEW7: This covers chart type 2 and we have completed this exercise under Flight Delay Time Statistics Dashboard section
            # Compute required information for creating graph from the data
            avg_car, avg_weather, avg_NAS, avg_sec, avg_late = compute_data_choice_2(df)
            
            # Create graph
            carrier_fig = px.line(avg_car, x='Month', y='CarrierDelay', color='Reporting_Airline', title='Average carrrier delay time (minutes) by airline')
            weather_fig = px.line(avg_weather, x='Month', y='WeatherDelay', color='Reporting_Airline', title='Average weather delay time (minutes) by airline')
            nas_fig = px.line(avg_NAS, x='Month', y='NASDelay', color='Reporting_Airline', title='Average NAS delay time (minutes) by airline')
            sec_fig = px.line(avg_sec, x='Month', y='SecurityDelay', color='Reporting_Airline', title='Average security delay time (minutes) by airline')
            late_fig = px.line(avg_late, x='Month', y='LateAircraftDelay', color='Reporting_Airline', title='Average late aircraft delay time (minutes) by airline')
            
            return[dcc.Graph(figure=carrier_fig), 
                   dcc.Graph(figure=weather_fig), 
                   dcc.Graph(figure=nas_fig), 
                   dcc.Graph(figure=sec_fig), 
                   dcc.Graph(figure=late_fig)]


# Run the app
if __name__ == '__main__':
    # REVIEW8: Adding dev_tools_ui=False, dev_tools_props_check=False can prevent error appearing before calling callback function
    app.run_server(mode="inline", host="localhost", debug=False, dev_tools_ui=False, dev_tools_props_check=False)
# Out:
# 127.0.0.1 - - [05/May/2021 23:03:00] "GET /_shutdown_ae8d06e4-7de3-4fb2-8b56-0523d44ddc95 HTTP/1.1" 200 -
#  * Running on http://localhost:8050/ (Press CTRL+C to quit)
# 127.0.0.1 - - [05/May/2021 23:03:02] "GET /_alive_ae8d06e4-7de3-4fb2-8b56-0523d44ddc95 HTTP/1.1" 200 -
#         <iframe
#             width="100%"
#             height="650"
#             src="http://localhost:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# 127.0.0.1 - - [05/May/2021 23:03:02] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2021 23:03:02] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2021 23:03:02] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [05/May/2021 23:03:02] "POST /_dash-update-component HTTP/1.1" 500 -
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-659070c5d794> in get_graph(
#     chart=None,
#     year=None,
#     children1=[],
#     children2=[],
#     c3=[],
#     c4=[],
#     c5=[]
# )
#     144
#     145         # Select data
# --> 146         df =  airline_data[airline_data['Year']==int(year)]
#         df = undefined
#         global airline_data =        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0         1295781  1998        2      4           2          4  1998-04-02
# 1         1125375  2013        2      5          13          1  2013-05-13
# 2          118824  1993        3      9          25          6  1993-09-25
# 3          634825  1994        4     11          12          6  1994-11-12
# 4         1888125  2017        3      8          17          4  2017-08-17
# ...           ...   ...      ...    ...         ...        ...         ...
# 26995      821542  2017        1      1          24          2  2017-01-24
# 26996     1910565  2013        2      6          27          4  2013-06-27
# 26997        9055  2016        3      8          26          5  2016-08-26
# 26998       84136  2009        3      8           8          6  2009-08-08
# 26999      113029  1993        3      7          17          6  1993-07-17
#
#       Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                    AS                     19930                          AS
# 1                    EV                     20366                          EV
# 2                    UA                     19977                          UA
# 3                    HP                     19991                          HP
# 4                    UA                     19977                          UA
# ...                 ...                       ...                         ...
# 26995                DL                     19790                          DL
# 26996                B6                     20409                          B6
# 26997                AA                     19805                          AA
# 26998                YV                     20378                          YV
# 26999                DL                     19790                          DL
#
#        ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# 0      ...           NaN          NaN          NaN            NaN
# 1      ...           NaN          NaN          NaN            NaN
# 2      ...           NaN          NaN          NaN            NaN
# 3      ...           NaN          NaN          NaN            NaN
# 4      ...           NaN          NaN          NaN            NaN
# ...    ...           ...          ...          ...            ...
# 26995  ...           NaN          NaN          NaN            NaN
# 26996  ...           NaN          NaN          NaN            NaN
# 26997  ...           NaN          NaN          NaN            NaN
# 26998  ...           NaN          NaN          NaN            NaN
# 26999  ...           NaN          NaN          NaN            NaN
#
#        Div5AirportSeqID Div5WheelsOn Div5TotalGTime Div5LongestGTime  \
# 0                   NaN          NaN            NaN              NaN
# 1                   NaN          NaN            NaN              NaN
# 2                   NaN          NaN            NaN              NaN
# 3                   NaN          NaN            NaN              NaN
# 4                   NaN          NaN            NaN              NaN
# ...                 ...          ...            ...              ...
# 26995               NaN          NaN            NaN              NaN
# 26996               NaN          NaN            NaN              NaN
# 26997               NaN          NaN            NaN              NaN
# 26998               NaN          NaN            NaN              NaN
# 26999               NaN          NaN            NaN              NaN
#
#        Div5WheelsOff Div5TailNum
# 0                NaN         NaN
# 1                NaN         NaN
# 2                NaN         NaN
# 3                NaN         NaN
# 4                NaN         NaN
# ...              ...         ...
# 26995            NaN         NaN
# 26996            NaN         NaN
# 26997            NaN         NaN
# 26998            NaN         NaN
# 26999            NaN         NaN
#
# [27000 rows x 110 columns]
#         global int = undefined
#         year = None
#     147
#     148         if chart == 'OPT1':
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# 127.0.0.1 - - [05/May/2021 23:14:29] "POST /_dash-update-component HTTP/1.1" 500 -
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-659070c5d794> in get_graph(
#     chart='OPT1',
#     year=None,
#     children1=[],
#     children2=[],
#     c3=[],
#     c4=[],
#     c5=[]
# )
#     144
#     145         # Select data
# --> 146         df =  airline_data[airline_data['Year']==int(year)]
#         df = undefined
#         global airline_data =        Unnamed: 0  Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0         1295781  1998        2      4           2          4  1998-04-02
# 1         1125375  2013        2      5          13          1  2013-05-13
# 2          118824  1993        3      9          25          6  1993-09-25
# 3          634825  1994        4     11          12          6  1994-11-12
# 4         1888125  2017        3      8          17          4  2017-08-17
# ...           ...   ...      ...    ...         ...        ...         ...
# 26995      821542  2017        1      1          24          2  2017-01-24
# 26996     1910565  2013        2      6          27          4  2013-06-27
# 26997        9055  2016        3      8          26          5  2016-08-26
# 26998       84136  2009        3      8           8          6  2009-08-08
# 26999      113029  1993        3      7          17          6  1993-07-17
#
#       Reporting_Airline  DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline  \
# 0                    AS                     19930                          AS
# 1                    EV                     20366                          EV
# 2                    UA                     19977                          UA
# 3                    HP                     19991                          HP
# 4                    UA                     19977                          UA
# ...                 ...                       ...                         ...
# 26995                DL                     19790                          DL
# 26996                B6                     20409                          B6
# 26997                AA                     19805                          AA
# 26998                YV                     20378                          YV
# 26999                DL                     19790                          DL
#
#        ... Div4WheelsOff  Div4TailNum  Div5Airport  Div5AirportID  \
# 0      ...           NaN          NaN          NaN            NaN
# 1      ...           NaN          NaN          NaN            NaN
# 2      ...           NaN          NaN          NaN            NaN
# 3      ...           NaN          NaN          NaN            NaN
# 4      ...           NaN          NaN          NaN            NaN
# ...    ...           ...          ...          ...            ...
# 26995  ...           NaN          NaN          NaN            NaN
# 26996  ...           NaN          NaN          NaN            NaN
# 26997  ...           NaN          NaN          NaN            NaN
# 26998  ...           NaN          NaN          NaN            NaN
# 26999  ...           NaN          NaN          NaN            NaN
#
#        Div5AirportSeqID Div5WheelsOn Div5TotalGTime Div5LongestGTime  \
# 0                   NaN          NaN            NaN              NaN
# 1                   NaN          NaN            NaN              NaN
# 2                   NaN          NaN            NaN              NaN
# 3                   NaN          NaN            NaN              NaN
# 4                   NaN          NaN            NaN              NaN
# ...                 ...          ...            ...              ...
# 26995               NaN          NaN            NaN              NaN
# 26996               NaN          NaN            NaN              NaN
# 26997               NaN          NaN            NaN              NaN
# 26998               NaN          NaN            NaN              NaN
# 26999               NaN          NaN            NaN              NaN
#
#        Div5WheelsOff Div5TailNum
# 0                NaN         NaN
# 1                NaN         NaN
# 2                NaN         NaN
# 3                NaN         NaN
# 4                NaN         NaN
# ...              ...         ...
# 26995            NaN         NaN
# 26996            NaN         NaN
# 26997            NaN         NaN
# 26998            NaN         NaN
# 26999            NaN         NaN
#
# [27000 rows x 110 columns]
#         global int = undefined
#         year = None
#     147
#     148         if chart == 'OPT1':
#
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# 127.0.0.1 - - [05/May/2021 23:17:31] "POST /_dash-update-component HTTP/1.1" 500 -
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-659070c5d794> in get_graph(
#     chart='OPT1',
#     year=2005,
#     children1=[],
#     children2=[],
#     c3=[],
#     c4=[],
#     c5=[]
# )
#     155             # TODO5: Average flight time by reporting airline
#     156
# --> 157             line_fig = px.line(line_data, x="Month", y="AirTime", color='Reporting Airline', title='Average monthly flight time (minutes) by airline')
#         line_fig = undefined
#         global px.line = <function line at 0x00000234B4DE0160>
#         line_data =      Month Reporting_Airline     AirTime
# 0        1                AA  186.857143
# 1        1                B6  156.000000
# 2        1                CO  144.333333
# 3        1                DH   64.250000
# 4        1                DL  120.400000
# ..     ...               ...         ...
# 201     12                OH   64.000000
# 202     12                OO   43.600000
# 203     12                UA  172.750000
# 204     12                WN  129.500000
# 205     12                XE   88.666667
#
# [206 rows x 3 columns]
#         global x = undefined
#         global y = undefined
#         global color = undefined
#         global title = undefined
#     158
#     159
#
# E:\Programs\Anaconda\lib\site-packages\plotly\express\_chart_types.py in line(
#     data_frame=     Month Reporting_Airline     AirTime
# 0      ...           XE   88.666667
#
# [206 rows x 3 columns],
#     x='Month',
#     y='AirTime',
#     line_group=None,
#     color='Reporting Airline',
#     line_dash=None,
#     hover_name=None,
#     hover_data=None,
#     custom_data=None,
#     text=None,
#     facet_row=None,
#     facet_col=None,
#     facet_col_wrap=0,
#     facet_row_spacing=None,
#     facet_col_spacing=None,
#     error_x=None,
#     error_x_minus=None,
#     error_y=None,
#     error_y_minus=None,
#     animation_frame=None,
#     animation_group=None,
#     category_orders=None,
#     labels=None,
#     orientation=None,
#     color_discrete_sequence=None,
#     color_discrete_map=None,
#     line_dash_sequence=None,
#     line_dash_map=None,
#     log_x=False,
#     log_y=False,
#     range_x=None,
#     range_y=None,
#     line_shape=None,
#     render_mode='auto',
#     title='Average monthly flight time (minutes) by airline',
#     template=None,
#     width=None,
#     height=None
# )
#     250     a polyline mark in 2D space.
#     251     """
# --> 252     return make_figure(args=locals(), constructor=go.Scatter)
#         global make_figure = <function make_figure at 0x00000234B4CC1790>
#         global args = undefined
#         global locals = undefined
#         global constructor = undefined
#         global go.Scatter = <class 'plotly.graph_objs._scatter.Scatter'>
#     253
#     254
#
# E:\Programs\Anaconda\lib\site-packages\plotly\express\_core.py in make_figure(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Reporting Airline', 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':      Month Reporting_Airline     AirTime
# 0      ...           XE   88.666667
#
# [206 rows x 3 columns], 'error_x': None, 'error_x_minus': None, ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>,
#     trace_patch={},
#     layout_patch={}
# )
#    1859     apply_default_cascade(args)
#    1860
# -> 1861     args = build_dataframe(args, constructor)
#         args = {'data_frame':      Month Reporting_Airline     AirTime
# 0        1                AA  186.857143
# 1        1                B6  156.000000
# 2        1                CO  144.333333
# 3        1                DH   64.250000
# 4        1                DL  120.400000
# ..     ...               ...         ...
# 201     12                OH   64.000000
# 202     12                OO   43.600000
# 203     12                UA  172.750000
# 204     12                WN  129.500000
# 205     12                XE   88.666667
#
# [206 rows x 3 columns], 'x': 'Month', 'y': 'AirTime', 'line_group': None, 'color': 'Reporting Airline', 'line_dash': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'line_dash_sequence': None, 'line_dash_map': None, 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'line_shape': None, 'render_mode': 'auto', 'title': 'Average monthly flight time (minutes) by airline', 'template': None, 'width': None, 'height': None}
#         global build_dataframe = <function build_dataframe at 0x00000234B4CC1430>
#         constructor = <class 'plotly.graph_objs._scatter.Scatter'>
#    1862     if constructor in [go.Treemap, go.Sunburst] and args["path"] is not None:
#    1863         args = process_dataframe_hierarchy(args)
#
# E:\Programs\Anaconda\lib\site-packages\plotly\express\_core.py in build_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Reporting Airline', 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':      Month Reporting_Airline     AirTime
# 0      ...           XE   88.666667
#
# [206 rows x 3 columns], 'error_x': None, 'error_x_minus': None, ...},
#     constructor=<class 'plotly.graph_objs._scatter.Scatter'>
# )
#    1375     # now that things have been prepped, we do the systematic rewriting of `args`
#    1376
# -> 1377     df_output, wide_id_vars = process_args_into_dataframe(
#         df_output = undefined
#         global wide_id_vars = undefined
#         global process_args_into_dataframe = <function process_args_into_dataframe at 0x00000234B4CC13A0>
#         args = {'data_frame':      Month Reporting_Airline     AirTime
# 0        1                AA  186.857143
# 1        1                B6  156.000000
# 2        1                CO  144.333333
# 3        1                DH   64.250000
# 4        1                DL  120.400000
# ..     ...               ...         ...
# 201     12                OH   64.000000
# 202     12                OO   43.600000
# 203     12                UA  172.750000
# 204     12                WN  129.500000
# 205     12                XE   88.666667
#
# [206 rows x 3 columns], 'x': 'Month', 'y': 'AirTime', 'line_group': None, 'color': 'Reporting Airline', 'line_dash': None, 'hover_name': None, 'hover_data': None, 'custom_data': None, 'text': None, 'facet_row': None, 'facet_col': None, 'facet_col_wrap': 0, 'facet_row_spacing': None, 'facet_col_spacing': None, 'error_x': None, 'error_x_minus': None, 'error_y': None, 'error_y_minus': None, 'animation_frame': None, 'animation_group': None, 'category_orders': None, 'labels': None, 'orientation': None, 'color_discrete_sequence': None, 'color_discrete_map': None, 'line_dash_sequence': None, 'line_dash_map': None, 'log_x': False, 'log_y': False, 'range_x': None, 'range_y': None, 'line_shape': None, 'render_mode': 'auto', 'title': 'Average monthly flight time (minutes) by airline', 'template': None, 'width': None, 'height': None}
#         wide_mode = False
#         var_name = None
#         value_name = None
#    1378         args, wide_mode, var_name, value_name
#    1379     )
#
# E:\Programs\Anaconda\lib\site-packages\plotly\express\_core.py in process_args_into_dataframe(
#     args={'animation_frame': None, 'animation_group': None, 'category_orders': None, 'color': 'Reporting Airline', 'color_discrete_map': None, 'color_discrete_sequence': None, 'custom_data': None, 'data_frame':      Month Reporting_Airline     AirTime
# 0      ...           XE   88.666667
#
# [206 rows x 3 columns], 'error_x': None, 'error_x_minus': None, ...},
#     wide_mode=False,
#     var_name=None,
#     value_name=None
# )
#    1181                         if argument == "index":
#    1182                             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1183                         raise ValueError(err_msg)
#         global ValueError = undefined
#         err_msg = "Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['Month', 'Reporting_Airline', 'AirTime'] but received: Reporting Airline"
#    1184                 elif length and len(df_input[argument]) != length:
#    1185                     raise ValueError(
#
# ValueError: Value of 'color' is not the name of a column in 'data_frame'. Expected one of ['Month', 'Reporting_Airline', 'AirTime'] but received: Reporting Airline

# %%
pip install jupyter_plotly_dash
# Out:
# Collecting jupyter_plotly_dash
#   Downloading jupyter_plotly_dash-0.4.3-py3-none-any.whl (29 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.7.4.post0-cp38-cp38-win_amd64.whl (635 kB)
# Collecting nbserverproxy
#   Downloading nbserverproxy-0.8.8-py3-none-any.whl (7.5 kB)
# Collecting django-bootstrap4
#   Downloading django_bootstrap4-3.0.1-py3-none-any.whl (24 kB)
# Collecting dpd-static-support
#   Downloading dpd_static_support-0.0.5-py3-none-any.whl (509 kB)
# Collecting dpd-components
#   Downloading dpd_components-0.1.0.tar.gz (4.3 kB)
# Collecting django-plotly-dash
#   Downloading django_plotly_dash-1.6.3-py3-none-any.whl (50 kB)
# Requirement already satisfied: jupyter in e:\programs\anaconda\lib\site-packages (from jupyter_plotly_dash) (1.0.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in e:\programs\anaconda\lib\site-packages (from aiohttp->jupyter_plotly_dash) (3.0.4)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-5.1.0-cp38-cp38-win_amd64.whl (48 kB)
# Requirement already satisfied: attrs>=17.3.0 in e:\programs\anaconda\lib\site-packages (from aiohttp->jupyter_plotly_dash) (20.3.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in e:\programs\anaconda\lib\site-packages (from aiohttp->jupyter_plotly_dash) (3.7.4.3)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.6.3-cp38-cp38-win_amd64.whl (125 kB)
# Collecting async-timeout<4.0,>=3.0
#   Downloading async_timeout-3.0.1-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: notebook in e:\programs\anaconda\lib\site-packages (from nbserverproxy->jupyter_plotly_dash) (6.1.4)
# Collecting Django>=2.2
#   Downloading Django-3.2.1-py3-none-any.whl (7.9 MB)
# Requirement already satisfied: beautifulsoup4>=4.8.0 in e:\programs\anaconda\lib\site-packages (from django-bootstrap4->jupyter_plotly_dash) (4.9.3)
# Requirement already satisfied: dash-core-components in e:\programs\anaconda\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.16.0)
# Requirement already satisfied: Flask>=1.0.2 in e:\programs\anaconda\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.1.2)
# Requirement already satisfied: plotly in e:\programs\anaconda\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (4.14.3)
# Requirement already satisfied: dash-html-components in e:\programs\anaconda\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.1.3)
# Requirement already satisfied: dash-renderer in e:\programs\anaconda\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.9.1)
# Requirement already satisfied: dash>=1.11 in e:\programs\anaconda\lib\site-packages (from django-plotly-dash->jupyter_plotly_dash) (1.20.0)
# Requirement already satisfied: ipykernel in e:\programs\anaconda\lib\site-packages (from jupyter->jupyter_plotly_dash) (5.3.4)
# Requirement already satisfied: nbconvert in e:\programs\anaconda\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.0.7)
# Requirement already satisfied: qtconsole in e:\programs\anaconda\lib\site-packages (from jupyter->jupyter_plotly_dash) (4.7.7)
# Requirement already satisfied: ipywidgets in e:\programs\anaconda\lib\site-packages (from jupyter->jupyter_plotly_dash) (7.5.1)
# Requirement already satisfied: jupyter-console in e:\programs\anaconda\lib\site-packages (from jupyter->jupyter_plotly_dash) (6.2.0)
# Requirement already satisfied: idna>=2.0 in e:\programs\anaconda\lib\site-packages (from yarl<2.0,>=1.0->aiohttp->jupyter_plotly_dash) (2.10)
# Requirement already satisfied: jinja2 in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (2.11.2)
# Requirement already satisfied: nbformat in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (5.0.8)
# Requirement already satisfied: prometheus-client in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (0.8.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (4.6.3)
# Requirement already satisfied: jupyter-client>=5.3.4 in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (6.1.7)
# Requirement already satisfied: terminado>=0.8.3 in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (0.9.1)
# Requirement already satisfied: pyzmq>=17 in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (19.0.2)
# Requirement already satisfied: traitlets>=4.2.1 in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (5.0.5)
# Requirement already satisfied: argon2-cffi in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (20.1.0)
# Requirement already satisfied: Send2Trash in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (1.5.0)
# Requirement already satisfied: ipython-genutils in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: tornado>=5.0 in e:\programs\anaconda\lib\site-packages (from notebook->nbserverproxy->jupyter_plotly_dash) (6.0.4)
# Collecting asgiref<4,>=3.3.2
#   Downloading asgiref-3.3.4-py3-none-any.whl (22 kB)
# Collecting sqlparse>=0.2.2
#   Downloading sqlparse-0.4.1-py3-none-any.whl (42 kB)
# Requirement already satisfied: pytz in e:\programs\anaconda\lib\site-packages (from Django>=2.2->django-bootstrap4->jupyter_plotly_dash) (2020.1)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in e:\programs\anaconda\lib\site-packages (from beautifulsoup4>=4.8.0->django-bootstrap4->jupyter_plotly_dash) (2.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in e:\programs\anaconda\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.1.0)
# Requirement already satisfied: click>=5.1 in e:\programs\anaconda\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (7.1.2)
# Requirement already satisfied: Werkzeug>=0.15 in e:\programs\anaconda\lib\site-packages (from Flask>=1.0.2->django-plotly-dash->jupyter_plotly_dash) (1.0.1)
# Requirement already satisfied: retrying>=1.3.3 in e:\programs\anaconda\lib\site-packages (from plotly->django-plotly-dash->jupyter_plotly_dash) (1.3.3)
# Requirement already satisfied: six in e:\programs\anaconda\lib\site-packages (from plotly->django-plotly-dash->jupyter_plotly_dash) (1.15.0)
# Requirement already satisfied: flask-compress in e:\programs\anaconda\lib\site-packages (from dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (1.9.0)
# Requirement already satisfied: future in e:\programs\anaconda\lib\site-packages (from dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (0.18.2)
# Requirement already satisfied: dash-table==4.11.3 in e:\programs\anaconda\lib\site-packages (from dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (4.11.3)
# Requirement already satisfied: ipython>=5.0.0 in e:\programs\anaconda\lib\site-packages (from ipykernel->jupyter->jupyter_plotly_dash) (7.19.0)
# Requirement already satisfied: testpath in e:\programs\anaconda\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.4.4)
# Requirement already satisfied: bleach in e:\programs\anaconda\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (3.2.1)
# Requirement already satisfied: pygments>=2.4.1 in e:\programs\anaconda\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (2.7.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in e:\programs\anaconda\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in e:\programs\anaconda\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in e:\programs\anaconda\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in e:\programs\anaconda\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in e:\programs\anaconda\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.5.1)
# Requirement already satisfied: defusedxml in e:\programs\anaconda\lib\site-packages (from nbconvert->jupyter->jupyter_plotly_dash) (0.6.0)
# Requirement already satisfied: qtpy in e:\programs\anaconda\lib\site-packages (from qtconsole->jupyter->jupyter_plotly_dash) (1.9.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in e:\programs\anaconda\lib\site-packages (from ipywidgets->jupyter->jupyter_plotly_dash) (3.5.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in e:\programs\anaconda\lib\site-packages (from jupyter-console->jupyter->jupyter_plotly_dash) (3.0.8)
# Requirement already satisfied: MarkupSafe>=0.23 in e:\programs\anaconda\lib\site-packages (from jinja2->notebook->nbserverproxy->jupyter_plotly_dash) (1.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in e:\programs\anaconda\lib\site-packages (from nbformat->notebook->nbserverproxy->jupyter_plotly_dash) (3.2.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in e:\programs\anaconda\lib\site-packages (from jupyter-core>=4.6.1->notebook->nbserverproxy->jupyter_plotly_dash) (227)
# Requirement already satisfied: python-dateutil>=2.1 in e:\programs\anaconda\lib\site-packages (from jupyter-client>=5.3.4->notebook->nbserverproxy->jupyter_plotly_dash) (2.8.1)
# Requirement already satisfied: pywinpty>=0.5 in e:\programs\anaconda\lib\site-packages (from terminado>=0.8.3->notebook->nbserverproxy->jupyter_plotly_dash) (0.5.7)
# Requirement already satisfied: cffi>=1.0.0 in e:\programs\anaconda\lib\site-packages (from argon2-cffi->notebook->nbserverproxy->jupyter_plotly_dash) (1.14.3)
# Requirement already satisfied: brotli in e:\programs\anaconda\lib\site-packages (from flask-compress->dash>=1.11->django-plotly-dash->jupyter_plotly_dash) (1.0.9)
# Requirement already satisfied: pickleshare in e:\programs\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.7.5)
# Requirement already satisfied: colorama; sys_platform == "win32" in e:\programs\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.4.4)
# Requirement already satisfied: backcall in e:\programs\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.2.0)
# Requirement already satisfied: decorator in e:\programs\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (4.4.2)
# Requirement already satisfied: setuptools>=18.5 in e:\programs\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (50.3.1.post20201107)
# Requirement already satisfied: jedi>=0.10 in e:\programs\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.17.1)
# Requirement already satisfied: packaging in e:\programs\anaconda\lib\site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (20.4)
# Requirement already satisfied: webencodings in e:\programs\anaconda\lib\site-packages (from bleach->nbconvert->jupyter->jupyter_plotly_dash) (0.5.1)
# Requirement already satisfied: nest-asyncio in e:\programs\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->jupyter_plotly_dash) (1.4.2)
# Requirement already satisfied: async-generator in e:\programs\anaconda\lib\site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->jupyter_plotly_dash) (1.10)
# Requirement already satisfied: wcwidth in e:\programs\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter->jupyter_plotly_dash) (0.2.5)
# Requirement already satisfied: pyrsistent>=0.14.0 in e:\programs\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->nbserverproxy->jupyter_plotly_dash) (0.17.3)
# Requirement already satisfied: pycparser in e:\programs\anaconda\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook->nbserverproxy->jupyter_plotly_dash) (2.20)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in e:\programs\anaconda\lib\site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->jupyter->jupyter_plotly_dash) (0.7.0)
# Requirement already satisfied: pyparsing>=2.0.2 in e:\programs\anaconda\lib\site-packages (from packaging->bleach->nbconvert->jupyter->jupyter_plotly_dash) (2.4.7)
# Building wheels for collected packages: dpd-components
#   Building wheel for dpd-components (setup.py): started
#   Building wheel for dpd-components (setup.py): finished with status 'done'
#   Created wheel for dpd-components: filename=dpd_components-0.1.0-py3-none-any.whl size=4571 sha256=ee21b09e083ec07de6bb230c2c2d2f47b50caf2eff089e1c1e288f0297a2a982
#   Stored in directory: c:\users\shirpls\appdata\local\pip\cache\wheels\07\a3\74\51b984d053f5e36de2d3bdfeb5dbadec7896d0af2dd7f4446e
# Successfully built dpd-components
# Installing collected packages: multidict, yarl, async-timeout, aiohttp, nbserverproxy, asgiref, sqlparse, Django, django-bootstrap4, dpd-static-support, dpd-components, django-plotly-dash, jupyter-plotly-dash
# Successfully installed Django-3.2.1 aiohttp-3.7.4.post0 asgiref-3.3.4 async-timeout-3.0.1 django-bootstrap4-3.0.1 django-plotly-dash-1.6.3 dpd-components-0.1.0 dpd-static-support-0.0.5 jupyter-plotly-dash-0.4.3 multidict-5.1.0 nbserverproxy-0.8.8 sqlparse-0.4.1 yarl-1.6.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output, State
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
from dash import no_update

# %%
JupyterDash.infer_jupyter_proxy_config()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-2-aac7d3a89f28> in <module>
# ----> 1 JupyterDash.infer_jupyter_proxy_config()
#
# E:\Programs\Anaconda\lib\site-packages\jupyter_dash\jupyter_app.py in infer_jupyter_proxy_config(cls)
#      71         else:
#      72             # Assume classic notebook or JupyterLab
# ---> 73             _request_jupyter_config()
#      74
#      75     def __init__(self, name=None, server_url=None, **kwargs):
#
# E:\Programs\Anaconda\lib\site-packages\jupyter_dash\comms.py in _request_jupyter_config(timeout)
#      60         if (time.time() - t0) > timeout:
#      61             # give up
# ---> 62             raise EnvironmentError(
#      63                 "Unable to communicate with the jupyter_dash notebook or JupyterLab \n"
#      64                 "extension required to infer Jupyter configuration."
#
# OSError: Unable to communicate with the jupyter_dash notebook or JupyterLab
# extension required to infer Jupyter configuration.
